# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !git clone https://github.com/nmkhoi3006/MediCLIP.git MediCLIP
# %cd /content/MediCLIP
# Out:
# /content
# Cloning into 'MediCLIP'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 111 (delta 54), reused 15 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (111/111), 2.20 MiB | 23.28 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /content/MediCLIP

# %%
# !mkdir -p data
# !ln -s /content/drive/MyDrive/MediCLIP_data/brainmri data/brainmri
# !ln -s /content/drive/MyDrive/MediCLIP_data/busi data/busi
# !ln -s /content/drive/MyDrive/MediCLIP_data/chexpert data/chexpert

# %%
import yaml

config_path = "config/brainmri.yaml"

with open(config_path, "r") as f:
    cfg = yaml.safe_load(f)

cfg["batch_size"] = 4
cfg["save_root"] = "/content/drive/MyDrive/MediCLIP_results"

with open(config_path, "w") as f:
    yaml.safe_dump(cfg, f, sort_keys=False)
